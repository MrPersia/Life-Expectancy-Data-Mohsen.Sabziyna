# %%
import pandas as pd
from pandas import DataFrame
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from matplotlib import rcParams
import plotly.graph_objects as go
import plotly.express as px
from plotly.colors import n_colors
import numpy as np
import seaborn as sns
import scipy.stats
from scipy.stats.mstats import winsorize
import warnings
warnings.filterwarnings("ignore")
life_expectancy = pd.read_csv("Life Expectancy Data.csv") #reading the file
life_expectancy.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
life_expectancy.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
life_expectancy.rename(columns = {" BMI " :"BMI", 
                                  "Life expectancy ": "Life_expectancy",
                                  "Adult Mortality":"Adult_mortality",
                                  "infant deaths":"Infant_deaths",
                                  "percentage expenditure":"Percentage_expenditure",
                                  "Hepatitis B":"HepatitisB",
                                  "Measles ":"Measles",
                                  "under-five deaths ": "Under_five_deaths",
                                  "Total expenditure":"Total_expenditure",
                                  "Diphtheria ": "Diphtheria",
                                  " thinness  1-19 years":"Thinness_1-19_years",
                                  " thinness 5-9 years":"Thinness_5-9_years",
                                  " HIV/AIDS":"HIV/AIDS",
                                  "Income composition of resources":"Income_composition_of_resources"}, inplace = True)

# %%
life_expectancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life_expectancy                  2928 non-null   float64
#  4   Adult_mortality                  2928 non-null   float64
#  5   Infant_deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   Percentage_expenditure           2938 non-null   float64
#  8   HepatitisB                       2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10  BMI                              2904 non-null   float64
#  11  Under_five_deaths                2938 non-null   int64
# ...

# %%
life_expectancy.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life_expectancy                     10
# Adult_mortality                     10
# Infant_deaths                        0
# Alcohol                            194
# Percentage_expenditure               0
# HepatitisB                         553
# Measles                              0
# BMI                                 34
# Under_five_deaths                    0
# Polio                               19
# Total_expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# Thinness_1-19_years                 34
# Thinness_5-9_years                  34
# Income_composition_of_resources    167
# Schooling                          163
# dtype: int64

# %%
life_expectancy.describe()
# Out:
#               Year  Life_expectancy  Adult_mortality  Infant_deaths  \
# count  2938.000000      2928.000000      2928.000000    2938.000000
# mean   2007.518720        69.224932       164.796448      30.303948
# std       4.613841         9.523867       124.292079     117.926501
# min    2000.000000        36.300000         1.000000       0.000000
# 25%    2004.000000        63.100000        74.000000       0.000000
# 50%    2008.000000        72.100000       144.000000       3.000000
# 75%    2012.000000        75.700000       228.000000      22.000000
# max    2015.000000        89.000000       723.000000    1800.000000
#
#            Alcohol  Percentage_expenditure   HepatitisB        Measles  \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
life_expectancy.reset_index(inplace=True)
life_expectancy.groupby('Country').apply(lambda group: group.interpolate(method= 'linear'))
imputed_data = []
for year in list(life_expectancy.Year.unique()):
    year_data = life_expectancy[life_expectancy.Year == year].copy()
    for col in list(year_data.columns)[4:]:
        year_data[col] = year_data[col].fillna(year_data[col].dropna().median()).copy()
    imputed_data.append(year_data)
life_expectancy = pd.concat(imputed_data).copy()

# %%
col_dict = {'Life_expectancy':1,'Adult_mortality':2,'Infant_deaths':3,'Alcohol':4,'Percentage_expenditure':5,'HepatitisB':6,'Measles':7,'BMI':8,'Under_five_deaths':9,'Polio':10,'Total_expenditure':11,'Diphtheria':12,'HIV/AIDS':13,'GDP':14,'Population':15,'Thinness_1-19_years':16,'Thinness_5-9_years':17,'Income_composition_of_resources':18,'Schooling':19}

# Detect outliers in each variable using box plots.
fig = plt.figure(figsize=(20,30))

for variable,i in col_dict.items():
                     plt.subplot(5,4,i)
                     plt.boxplot(life_expectancy[variable])
                     plt.title(variable)
                     plt.grid(True)

# %%
life_expectancy = life_expectancy[life_expectancy['Infant_deaths'] < 1001]
life_expectancy = life_expectancy[life_expectancy['Measles'] < 1001]
life_expectancy = life_expectancy[life_expectancy['Under_five_deaths'] < 1001]

life_expectancy.drop(['BMI'], axis=1, inplace=True)
life_expectancy['log_Percentage_expenditure'] = np.log(life_expectancy['Percentage_expenditure'])
life_expectancy['log_Population'] = np.log(life_expectancy['Population'])
life_expectancy['log_GDP'] = np.log(life_expectancy['GDP'])
life_expectancy = life_expectancy.replace([np.inf, -np.inf], 0)
life_expectancy['log_Percentage_expenditure']

life_expectancy['winz_Life_expectancy'] = winsorize(life_expectancy['Life_expectancy'], (0.05,0))
life_expectancy['winz_Adult_mortality'] = winsorize(life_expectancy['Adult_mortality'], (0,0.04))
life_expectancy['winz_Alcohol'] = winsorize(life_expectancy['Alcohol'], (0.0,0.01))
life_expectancy['winz_HepatitisB'] = winsorize(life_expectancy['HepatitisB'], (0.20,0.0))
life_expectancy['winz_Polio'] = winsorize(life_expectancy['Polio'], (0.20,0.0))
life_expectancy['winz_Total_expenditure'] = winsorize(life_expectancy['Total_expenditure'], (0.0,0.02))
life_expectancy['winz_Diphtheria'] = winsorize(life_expectancy['Diphtheria'], (0.11,0.0))
life_expectancy['winz_HIV/AIDS'] = winsorize(life_expectancy['HIV/AIDS'], (0.0,0.21))
life_expectancy['winz_Thinness_1-19_years'] = winsorize(life_expectancy['Thinness_1-19_years'], (0.0,0.04))
life_expectancy['winz_Thinness_5-9_years'] = winsorize(life_expectancy['Thinness_5-9_years'], (0.0,0.04))
life_expectancy['winz_Income_composition_of_resources'] = winsorize(life_expectancy['Income_composition_of_resources'], (0.05,0.0))
life_expectancy['winz_Schooling'] = winsorize(life_expectancy['Schooling'], (0.03,0.01))

col_dict_winz = {'winz_Life_expectancy':1,'winz_Adult_mortality':2,'Infant_deaths':3,'winz_Alcohol':4,
            'log_Percentage_expenditure':5,'winz_HepatitisB':6,'Measles':7,'Under_five_deaths':8,'winz_Polio':9,
            'winz_Total_expenditure':10,'winz_Diphtheria':11,'winz_HIV/AIDS':12,'log_GDP':13,'log_Population':14,
            'winz_Thinness_1-19_years':15,'winz_Thinness_5-9_years':16,'winz_Income_composition_of_resources':17,
            'winz_Schooling':18}


fig = plt.figure(figsize=(20,20))
for variable,i in col_dict_winz.items():
                     plt.subplot(5,6,i)
                     sns.boxplot(y = life_expectancy[variable], color = "pink")
                     plt.title(variable)
                     plt.ylabel('')
                     
                     plt.grid(True)
    
plt.show()

# %%
fig = plt.figure(figsize=(20,20))
for variable,i in col_dict_winz.items():
                     plt.subplot(5,6,i)
                     plt.hist(life_expectancy[variable])
                     plt.title(variable)
                     plt.ylabel('')
                     
                     plt.grid(True)
    
plt.tight_layout()
plt.show()

# %%
life_exp = life_expectancy[['Year','winz_Life_expectancy','winz_Adult_mortality','Infant_deaths','winz_Alcohol',
            'log_Percentage_expenditure','winz_HepatitisB','Measles','Under_five_deaths','winz_Polio',
            'winz_Total_expenditure','winz_Diphtheria','winz_HIV/AIDS','log_GDP','log_Population',
            'winz_Thinness_1-19_years','winz_Thinness_5-9_years','winz_Income_composition_of_resources',
            'winz_Schooling']]
plt.figure(figsize=(15,10))
sns.heatmap(life_exp.corr(), annot =True, linewidths = 4)
# Out:
# <Axes: >

# %% [markdown]
# - **Adult Mortalität** hat eine negative Beziehung zu Bildung, Einkommenszusammensetzung und eine positive Beziehung zu HIV/AIDS.
# - **Säuglings- und Kleinkindsterblichkeit** haben eine starke positive Beziehung.
# - **Bildung (Schulbildung)** und **Alkoholkonsum** haben eine positive Beziehung.
# - **Prozentsatz der Ausgaben** hat eine positive Beziehung zu Bildung, Einkommenszusammensetzung, Bruttoinlandsprodukt (BIP) und Lebenserwartung.
# - **Hepatitis B** hat eine starke positive Beziehung zu Polio und Diphtherie.
# - **Polio** hat auch eine starke positive Beziehung zu Diphtherie, Hepatitis B und Lebenserwartung.
# - **Diphtherie** hat eine starke positive Beziehung zu Polio und Lebenserwartung.
# - **Lebenserwartung** hat eine positive Beziehung zu Bildung, Einkommenszusammensetzung, Bruttoinlandsprodukt (BIP), Diphtherie, Polio und prozentualen Ausgaben.
# - **Lebenserwartung** hat eine negative Beziehung zu Adult Mortalität, Dünne 1-19 Jahre, Dünne 5-9 Jahre, HIV/AIDS, Unter-5-Todesfällen und Säuglingssterblichkeit.

# %%
import seaborn as sns

status_life_exp = life_expectancy.groupby(by=['Status'])['winz_Life_expectancy'].mean().reset_index().sort_values('winz_Life_expectancy', ascending=False)

plt.figure(figsize=(12, 8))
ax = sns.barplot(data=status_life_exp, x='Status', y='winz_Life_expectancy', palette='viridis')

for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=12, color='black', xytext=(0, 5), textcoords='offset points')

plt.title("Durchschnittliche Lebenserwartung nach Status", fontsize=16)
plt.xlabel("Status", fontsize=14)
plt.ylabel("Durchschnittliche Lebenserwartung", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

palette = {'Entwickelte Länder': '#00FFFF', 'Entwicklungsländer': '#FF69B4'}

life_year = life_expectancy.groupby(by=['Year', 'Status'])['winz_Life_expectancy'].mean().reset_index()

Developed = life_year[life_year['Status'] == 'Developed']
Developing = life_year[life_year['Status'] == 'Developing']

plt.figure(figsize=(12, 8))

sns.lineplot(data=Developed, x='Year', y='winz_Life_expectancy', color=palette['Entwickelte Länder'], label='Entwickelte Länder')
for i, row in Developed.iterrows():
    plt.text(row['Year'], row['winz_Life_expectancy'], f"{row['winz_Life_expectancy']:.2f}", fontsize=10, color=palette['Entwickelte Länder'], ha='left')

sns.lineplot(data=Developing, x='Year', y='winz_Life_expectancy', color=palette['Entwicklungsländer'], label='Entwicklungsländer')
for i, row in Developing.iterrows():
    plt.text(row['Year'], row['winz_Life_expectancy'], f"{row['winz_Life_expectancy']:.2f}", fontsize=10, color=palette['Entwicklungsländer'], ha='left')

plt.title('Durchschnittliche Lebenserwartung von Entwicklungs- und Industrieländern im Laufe der Jahre', fontsize=16)
plt.xlabel('Jahr', fontsize=14)
plt.ylabel('Durchschnittliche Lebenserwartung (Jahre)', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.legend(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.style.use('dark_background')

plt.tight_layout()
plt.show()

# %% [markdown]
# In der Analyse der Lebenserwartung wurde ein Datensatz untersucht, der verschiedene Gesundheits- und Entwicklungsindikatoren für verschiedene Länder enthält. Zunächst wurden fehlende Werte durch lineare Interpolation und Medianimputation behandelt. Anschließend wurden Ausreißerwerte bereinigt und logarithmische Transformationen für einige Variablen durchgeführt. Die Daten wurden dann in Bezug auf verschiedene Faktoren wie Erwachsenensterblichkeit, Bildung, Infektionskrankheiten usw. analysiert. Es wurde festgestellt, dass entwickelte Länder im Allgemeinen eine höhere Lebenserwartung haben als Entwicklungsländer. Dies wird durch die Analyse von durchschnittlichen Lebenserwartungswerten im Laufe der Jahre für beide Ländergruppen bestätigt.
